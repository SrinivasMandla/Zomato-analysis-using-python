# %% [markdown]
# <a href="https://colab.research.google.com/github/SrinivasMandla/Zomato-analysis-using-python/blob/main/ZOMATO_DATA_ANALYSIS_USING_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# CREATE THE DATAFRAME

# %%
dataframe=pd.read_csv("/content/Zomato-data-.csv")

# %%
dataframe
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
print(dataframe)
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %% [markdown]
# **CONVERT THE DATATYPE OF COLUMN-RATE**

# %%
def handleRate(value):
  value=str(value).split('/')
  value=value[0];
  return float(value);

# %%
dataframe['rate']=dataframe['rate'].apply(handleRate)
print (dataframe['rate'])
# Out:
# 0      4.1
# 1      4.1
# 2      3.8
# 3      3.7
# 4      3.8
#       ...
# 143    3.3
# 144    3.3
# 145    4.0
# 146    3.0
# 147    3.9
# Name: rate, Length: 148, dtype: float64

# %%
print(dataframe.head())
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    float64
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 8.2+ KB

# %% [markdown]
# **Q1.WHAT TYPE OF RESTAURENT WHERE MAJORITY OF CUSTOMERS ORDER FROM?**

# %%
dataframe.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
sns.countplot(x=dataframe['listed_in(type)'])
plt.xlabel("type of restaurent")
# Out:
# Text(0.5, 0, 'type of restaurent')

# %% [markdown]
# **1)ANSWER: DINNING RESTAURENT**

# %%
dataframe.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %% [markdown]
# **Q2.HOW MANY VOTES HAS EACH TYPE OF RESTAURENT RECEIVED FROM CUSTOMERS?** **bold text**

# %%
grouped_data=dataframe.groupby('listed_in(type)')['votes'].sum()
result = pd.DataFrame({'votes':grouped_data}) # Change 'dataframe' to 'DataFrame'
plt.plot(result,c="green",marker="*")
plt.xlabel("type of restaurent",c="black",size=20)
plt.ylabel("votes",c="BLACK",size=20)
plt.title("votes of restaurent",c="BLACK",size=20)
# Out:
# Text(0.5, 1.0, 'votes of restaurent')

# %% [markdown]
# **2)ANSWER: DINNING RESTAURENT HAS RECIEVED MAXIMMUM VOTES**

# %%
print(dataframe["votes"])
# Out:
# 0      775
# 1      787
# 2      918
# 3       88
# 4      166
#       ...
# 143      0
# 144      0
# 145    771
# 146     98
# 147     47
# Name: votes, Length: 148, dtype: int64

# %% [markdown]
# **Q3:WHAT ARE THE RATINGS THAT THE MAJORITY OF RESTAURENTS HAVE RECEIVED?**

# %%
dataframe.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
plt.hist (dataframe['rate'],bins=5)
plt.title("ratings distribution")
plt.show()

# %% [markdown]
# **3)ANSWER: THE MAJORITY RESTAURENTS RECEVIED RATINGS FROM 3.5 TO 4**

# %% [markdown]
# **Q3.ZOMATO HAS OBSERVED THAT MOST COUPLES ORDER MOST OF THEIR FOOD. WHAT IS THEIR AVERAGE SPENDING ON EACH ORDER**

# %%
dataframe.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
couple_data=dataframe['approx_cost(for two people)']
sns.countplot(x=couple_data)
# Out:
# <Axes: xlabel='approx_cost(for two people)', ylabel='count'>

# %% [markdown]
# **4)ANSWER: THE MAJORITY OF COUPLES PREFERR RESTURANTS WITH AN APPROXIMATE COST OF 300 RUPEES**

# %% [markdown]
# **Q5. WHICH MODE (ONLINE OR OFFLINE) HAS RECEVIED THE MAXIMUM RATING?**

# %%
dataframe.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='online_order',y = 'rate', data=dataframe)
# Out:
# <Axes: xlabel='online_order', ylabel='rate'>

# %% [markdown]
# **4)ANSWER: ONLINE ORDER RECEVIED HIGHER RATING THAN OFFLINE ORDER**

# %%
dataframe.head(10)
# Out:
#                                               name online_order book_table  \
# 0                                            Jalsa          Yes        Yes
# 1                                   Spice Elephant          Yes         No
# 2                                  San Churro Cafe          Yes         No
# 3                            Addhuri Udupi Bhojana           No         No
# 4                                    Grand Village           No         No
# 5                                  Timepass Dinner          Yes         No
# 6  Rosewood International Hotel - Bar & Restaurant           No         No
# 7                                           Onesta          Yes        Yes
# 8                                   Penthouse Cafe          Yes         No
# 9                                        Smacznego          Yes         No
#
#    rate  votes  approx_cost(for two people) listed_in(type)
# 0   4.1    775                          800          Buffet
# ...

# %%
dataframe.tail(10)
# Out:
#                              name online_order book_table  rate  votes  \
# 138  Sri Murari Family Restaurant           No         No   2.9      0
# 139        Aramane Donne Biriyani           No         No   2.9      0
# 140                    Darkolates           No         No   3.3      0
# 141        Swaada Healthy Kitchen           No         No   3.3      0
# 142         Gawdaru Mane Beriyani           No         No   3.3      0
# 143              Melting Melodies           No         No   3.3      0
# 144               New Indraprasta           No         No   3.3      0
# 145                  Anna Kuteera          Yes         No   4.0    771
# 146                        Darbar           No         No   3.0     98
# 147                 Vijayalakshmi          Yes         No   3.9     47
#
#      approx_cost(for two people) listed_in(type)
# 138                          250          Dining
# 139                          150          Dining
# ...

# %%
dataframe.describe()
# Out:
#              rate        votes  approx_cost(for two people)
# count  148.000000   148.000000                   148.000000
# mean     3.633108   264.810811                   418.243243
# std      0.402271   653.676951                   223.085098
# min      2.600000     0.000000                   100.000000
# 25%      3.300000     6.750000                   200.000000
# 50%      3.700000    43.500000                   400.000000
# 75%      3.900000   221.750000                   600.000000
# max      4.600000  4884.000000                   950.000000

# %% [markdown]
# **Q5. WHICH TYPE OF RESTAURENT RECEVIED
# MORE OFFLINE ORDERS, SO THAT ZOMATO CAN PROVIDE CUSTOMERS WITH SOME GOOD OFFERS:**

# %%
pivot_table=dataframe.pivot_table(index='listed_in(type)',columns='online_order',aggfunc='size', fill_value=0)
sns.heatmap(pivot_table,annot=True,cmap='YlGnBu')
plt.title("heatmap")
plt.xlabel("online_order")
plt.ylabel("listed_in(type)")
plt.show()

# %% [markdown]
# **5)ANSWER: DINNING RESTAURENTS PRIMARILY ACCEPT OFFLINE ORDERS, WHEREAS CAFES PRIMARILY RECEIVE ONLINE ORDERS. THIS SUGGESTS THAT CLIENTS PREFER ORDERS IN PERSON AT RESTAURENTS, BUT PREFER ONLINE ORDERING AT CAFES.**

# %% [markdown]
# **Q6) FIND TOP 10 RESTAURENTS ACCORDING TO RATINGS**
#
# ```
# # This is formatted as code
# ```
#
#
#
# > Add blockquote

# %%
dataframe[['name','rate']].sort_values(by='rate',ascending=False).head(10)
# Out:
#                       name  rate
# 44                  Onesta   4.6
# 7                   Onesta   4.6
# 38       Empire Restaurant   4.4
# 86           Meghana Foods   4.4
# 52  Corner House Ice Cream   4.3
# 37         Szechuan Dragon   4.2
# 60           Peppy Peppers   4.2
# 81           Frozen Bottle   4.2
# 12        The Coffee Shack   4.2
# 11            Cafe Shuffle   4.2

# %% [markdown]
# Insights from the Heatmap:
#
# * Dominant Dining Category:
#  The "Dining" category stands out with significantly higher numbers compared to "Cafes," "Buffet," and "other." This suggests a strong preference or larger market share for dining establishments.
#
# * Online Order Preference in Dining: Within the "Dining" category, there's a notable difference between "No" and "Yes" for online orders. The number "77" for "No" indicates that a substantial portion of dining customers prefer not to order online, while "33" for "Yes" shows a sizable portion does order online.
#
# * Lower Numbers in Other Categories: The numbers in "Cafes," "Buffet," and "other" categories are much lower compared to "Dining," indicating less activity or popularity in these segments.
#
# * Potential for Growth in Online Orders (Dining): Although a large portion prefers not to order online in the "Dining" category, the "Yes" number (33) suggests a considerable segment is open to online ordering. This indicates potential for growth in online orders within this category.
#
# * Limited Online Order Data in Other Categories: The low numbers in "Cafes," "Buffet," and "other" categories make it difficult to draw definitive conclusions about online order preferences in these segments.
#
# Actions Based on Insights:
#
# For the "Dining" Category:
#
# * Understand Offline Preference: Conduct surveys or focus groups to understand why a large portion of dining customers prefers not to order online.
# This will help tailor strategies to address concerns or improve online offerings.
#
# * Enhance Online Ordering Experience: Invest in improving the online ordering platform, making it user-friendly, offering exclusive deals, and ensuring seamless delivery or pickup options.
#
# * Targeted Marketing for Online Orders: Implement targeted marketing campaigns to promote online ordering within the "Dining" category. Highlight the convenience and benefits of ordering online.
#
# For "Cafes," "Buffet," and "Other" Categories:
#
# * Investigate Low Numbers: Conduct market research to understand the reasons for lower activity in these categories. Identify potential barriers to growth and explore opportunities for improvement.
#
# * Explore Online Order Potential: Despite low current numbers, explore the potential for online ordering in these categories. Experiment with online platforms and assess customer interest.
#
# * Niche Marketing: Consider niche marketing strategies to target specific customer segments within these categories.
#
# By combining the insights from the heatmap with a data-driven approach and a focus on customer understanding, businesses can make informed decisions to improve their online presence and overall performance.
